# %%
import numpy as np

from project.wfc.factory import Factory
from project.wfc.grid import Grid, Rect, Point
from project.visualization.grid_renderer import grid_renderer
from project.config import DATA_SOURCE, GRIDS_FOLDER
from project.wfc.repository import repository
from project.wfc.wfc import WFC
from project.wfc.judge import RandomJudge

# %%
factory = Factory(DATA_SOURCE)

patterns = factory.create_patterns()

rect = Rect(width=10, height=10)

grid = Grid(rect=rect, patterns=repository.get_all_patterns())

judge = RandomJudge(seed=None)

wfc = WFC(grid=grid, judge=judge)
# Out:
# INFO - Validation Result: success

# %%
if wfc.step(early_stopping=True).success:
    grid_renderer.draw(grid=grid, show_borders=False, seed=42, show=True)

# %%
grid.serialize(GRIDS_FOLDER, None)

# %%
tries = 0
is_succeeded = False

while is_succeeded != True: 
    tries += 1
    is_succeeded = wfc.generate()

tries
# Out:
# 4

# %%
TARGET = 1000

for _ in range(TARGET):
    is_succeeded = False
    while is_succeeded != True:
        is_succeeded = wfc.generate()
    grid.serialize(f"{GRIDS_FOLDER}test/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 7
#       5 while is_succeeded != True:
#       6     is_succeeded = wfc.generate()
# ----> 7 grid.serialize(f"{GRIDS_FOLDER}test/")
#
# File ~/Documents/GitHub/WFC-RI/project/wfc/grid.py:166, in Grid.serialize(self, path, name, property_func)
#     160     name = str(uuid.uuid4())
#     162 properties = self.get_patterns_property(
#     163     property_func=property_func, patterns=self.grid
#     164 )
# --> 166 with open(f"{path}{name}.dat", "w") as f:
#     167     for row in properties:
#     168         f.write(",".join(map(str, row)) + "\n")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/grids/test/094ad933-f1cb-482c-9d3e-dd34508491cd.dat'

# %%
grid_renderer.draw(grid=grid, show_borders=False, seed=42)
