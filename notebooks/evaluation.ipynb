# %%
from setup_env import setup_environment

setup_environment()

# %%
from project.machine_learning.dataset import Dataset
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
import matplotlib.pyplot as plt

# %%
wfc_df = Dataset.load_data("data/graphs/wfc")
wfcwmc_df = Dataset.load_data("data/graphs/wfcwmc")
# Out:
# /Users/evlko/Documents/GitHub/WFC-RI/project/machine_learning/dataset.py:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("Infinity", -1, inplace=True)
# /Users/evlko/Documents/GitHub/WFC-RI/project/machine_learning/dataset.py:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("Infinity", -1, inplace=True)

# %%
model = KElbowVisualizer(KMeans(n_init=10, random_state=42), k=20, timings=False, title=" ")
model.fit(wfc_df)
model.ax.set_ylim((0, 250))
model.show(outpath="content/wfc_elbow_plot.png",  bbox_inches="tight")
# Out:
# <Axes: title={'center': ' '}, xlabel='k', ylabel='distortion score'>

# %%
model = KElbowVisualizer(KMeans(n_init=10, random_state=42), k=20, timings=False, title=" ")
model.fit(wfcwmc_df)
model.ax.set_ylim((0, 250))
model.show(outpath="content/wfcwmc_elbow_plot.png",  bbox_inches="tight")
# Out:
# <Axes: title={'center': ' '}, xlabel='k', ylabel='distortion score'>
