# %%
import numpy as np

from project.wfc.factory import Factory
from project.config import DATA_SOURCE
from project.visualization.pattern_renderer import pattern_renderer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 from project.wfc.factory import Factory
#       4 from project.config import DATA_SOURCE
# ----> 5 from project.visualization.pattern_renderer import pattern_renderer
#
# File ~/Documents/GitHub/WFC-RI/project/visualization/pattern_renderer.py:4
#       1 import matplotlib.pyplot as plt
#       3 from project.wfc.pattern import Pattern
# ----> 4 from visualization.renderer import Renderer
#       7 class PatternRenderer(Renderer):
#       8     def draw(self, pattern: Pattern) -> None:
#
# ModuleNotFoundError: No module named 'visualization'

# %%
factory = Factory(DATA_SOURCE)
patterns = list(factory.create_patterns())

# %%
patterns
# Out:
# [Pattern(uid=1, image_path='images/tile_0048.png', name='Empty Ground', tags={'Ground'}, weight=1),
#  Pattern(uid=2, image_path='images/tile_0049.png', name='Ground with Stones', tags={'Ground'}, weight=1),
#  Pattern(uid=3, image_path='images/tile_0057.png', name='Left Wall Bottom End', tags={'Wall'}, weight=1),
#  Pattern(uid=4, image_path='images/tile_0014.png', name='Wall Center 1', tags={'Wall', 'Wall Center'}, weight=5),
#  Pattern(uid=5, image_path='images/tile_0040.png', name='Wall Center 2', tags={'Wall', 'Wall Center'}, weight=1),
#  Pattern(uid=6, image_path='images/tile_0059.png', name='Right Wall Bottom End', tags={'Wall'}, weight=1),
#  Pattern(uid=7, image_path='images/tile_0016.png', name='Left Wall Top End', tags={'Wall Bottom Top'}, weight=1),
#  Pattern(uid=8, image_path='images/tile_0002.png', name='Center Wall Top End', tags={'Wall Bottom Top'}, weight=1),
#  Pattern(uid=9, image_path='images/tile_0017.png', name='Right Wall Top End', tags={'Wall Bottom Top'}, weight=1),
#  Pattern(uid=10, image_path='images/tile_0015.png', name='Left Wall', tags={'Wall Left'}, weight=1),
#  Pattern(uid=11, image_path='images/tile_0013.png', name='Right Wall', tags={'Wall Right'}, weight=1),
#  Pattern(uid=12, image_path='images/tile_0050.png', name='Wall Ground', tags={'Wall Ground'}, weight=3),
#  Pattern(uid=13, image_path='images/tile_0051.png', name='Wall Ground with Stones', tags={'Wall Ground'}, weight=1),
#  Pattern(uid=14, image_path='images/tile_0000.png', name='Wall Inside 1', tags={'Wall Inside'}, weight=3),
#  Pattern(uid=15, image_path='images/tile_0012.png', name='Wall Inside 1', tags={'Wall Inside'}, weight=3)]

# %%
pattern_renderer.draw(pattern=patterns[11])
